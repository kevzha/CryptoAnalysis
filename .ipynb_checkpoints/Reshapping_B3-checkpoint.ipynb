# %%
import pandas as pd

# %%
ELA_reshaped = pd.read_csv("ELA")
KCS_reshaped = pd.read_csv("KCS")
WAN_reshaped = pd.read_csv("WAN")

# %%
ELA_reshaped = ELA_reshaped.drop(ELA_reshaped.index[326:]).drop(ELA_reshaped.index[0])

# %%
KCS_reshaped = KCS_reshaped.drop(KCS_reshaped.index[326:]).drop(KCS_reshaped.index[0])

# %%
WAN_reshaped = WAN_reshaped.drop(WAN_reshaped.index[0])

# %%
ELA_reshaped.head()
# Out:
#    Unnamed: 0          Date Open*  High   Low Close**     Volume  Market Cap  \
# 1           1  Feb 11, 2019  2.34  2.36  2.23    2.25    825,674  32,779,845
# 2           2  Feb 10, 2019  2.28  2.39  2.20    2.36  1,038,737  34,322,470
# 3           3  Feb 09, 2019  2.30  2.32  2.21    2.28    503,749  33,125,031
# 4           4  Feb 08, 2019  2.13  2.32  2.10    2.30  1,124,742  33,426,019
# 5           5  Feb 07, 2019  2.11  2.15  2.07    2.11    408,356  30,614,038
#
#    Close Percent Change
# 1              0.056338
# 2              0.048889
# 3             -0.033898
# 4              0.008772
# 5             -0.082609

# %%
KCS_reshaped.head()
# Out:
#    Unnamed: 0          Date     Open*      High       Low   Close**   Volume  \
# 1           1  Feb 11, 2019  0.372457  0.372965  0.357386  0.360186   74,144
# 2           2  Feb 10, 2019  0.373908  0.376798  0.366396  0.370683  113,364
# 3           3  Feb 09, 2019  0.367814  0.376134  0.364795  0.373724   77,250
# 4           4  Feb 08, 2019  0.349097  0.370431  0.341340  0.368694  136,393
# 5           5  Feb 07, 2019  0.353000  0.354022  0.344373  0.348911   31,603
#
#    Market Cap  Close Percent Change
# 1  32,395,108              0.033865
# 2  33,339,198              0.029143
# 3  33,612,734              0.008204
# 4  33,160,299             -0.013459
# 5  31,380,985             -0.053657

# %%
WAN_reshaped
# Out:
#      Unnamed: 0          Date               Open*      High       Low  \
# 1             1  Feb 11, 2019            0.292928  0.296669  0.287315
# 2             2  Feb 10, 2019            0.290055  0.292139  0.284831
# 3             3  Feb 09, 2019            0.292845  0.293144  0.283931
# 4             4  Feb 08, 2019            0.273142  0.296012  0.267220
# 5             5  Feb 07, 2019            0.282813  0.286318  0.270510
# 6             6  Feb 06, 2019            0.263348  0.283880  0.252161
# 7             7  Feb 05, 2019            0.271795  0.272879  0.261297
# 8             8  Feb 04, 2019            0.272061  0.277935  0.271110
# 9             9  Feb 03, 2019            0.275564  0.278519  0.270018
# 10           10  Feb 02, 2019            0.275846  0.277837  0.272373
# 11           11  Feb 01, 2019            0.276701  0.279454  0.265337
# 12           12  Jan 31, 2019            0.289539  0.293779  0.271358
# ...

# %%
ELA_reshaped.to_csv("ELA_reshaped.csv")

# %%
KCS_reshaped.to_csv("KCS_reshaped.csv")

# %%
WAN_reshaped.to_csv("WAN_reshaped.csv")
