# %%
from bs4 import BeautifulSoup
import requests
# Here, we're just importing both Beautiful Soup and the Requests library
# page_linkELA = ("https://coinmarketcap.com/currencies/elastos/historical-data/?start=20130428&end=20190212")
# page_linkKCS = ("https://coinmarketcap.com/currencies/kucoin-shares/historical-data/?start=20130428&end=20190212")
# page_linkWAN = ("https://coinmarketcap.com/currencies/wanchain/historical-data/?start=20130428&end=20190212")
page_linkVET = ("https://coinmarketcap.com/currencies/vechain/historical-data/?start=20130428&end=20190214")
page_linkTUSD = ("https://coinmarketcap.com/currencies/trueusd/historical-data/?start=20130428&end=20190214")
page_linkXVG = ("https://coinmarketcap.com/currencies/verge/historical-data/?start=20130428&end=20190214")
page_linkAE = ("https://coinmarketcap.com/currencies/aeternity/historical-data/?start=20130428&end=20190214")
page_linkSTRAT = ("https://coinmarketcap.com/currencies/stratis/historical-data/?start=20130428&end=20190214")
page_linkLRC = ("https://coinmarketcap.com/currencies/loopring/historical-data/?start=20130428&end=20190214")
page_linkAOA = ("https://coinmarketcap.com/currencies/aurora/historical-data/?start=20130428&end=20190214")
page_linkQNT = ("https://coinmarketcap.com/currencies/quant/historical-data/?start=20130428&end=20190214")

# this is the url that we've already determined is safe and legal to scrape from.
# page_responseELA = requests.get(page_linkELA, timeout=5)
# page_responseKCS= requests.get(page_linkKCS, timeout=5)
# page_responseWAN= requests.get(page_linkWAN, timeout=5)
page_responseVET= requests.get(page_linkVET, timeout=5)
page_responseTUSD= requests.get(page_linkTUSD, timeout=5)
page_responseXVG= requests.get(page_linkXVG, timeout=5)
page_responseAE= requests.get(page_linkAE, timeout=5)
page_responseSTRAT= requests.get(page_linkSTRAT, timeout=5)
page_responseLRC= requests.get(page_linkLRC, timeout=5)
page_responseAOA= requests.get(page_linkAOA, timeout=5)
page_responseQNT= requests.get(page_linkQNT, timeout=5)

# here, we fetch the content from the url, using the requests library
# page_contentELA = BeautifulSoup(page_responseELA.content, "html.parser")
# page_contentKCS = BeautifulSoup(page_responseKCS.content, "html.parser")
# page_contentWAN= BeautifulSoup(page_responseWAN.content, "html.parser")
page_contentVET= BeautifulSoup(page_responseVET.content, "html.parser")
page_contentTUSD= BeautifulSoup(page_responseTUSD.content, "html.parser")
page_contentXVG= BeautifulSoup(page_responseXVG.content, "html.parser")
page_contentAE= BeautifulSoup(page_responseAE.content, "html.parser")
page_contentSTRAT= BeautifulSoup(page_responseSTRAT.content, "html.parser")
page_contentLRC= BeautifulSoup(page_responseLRC.content, "html.parser")
page_contentAOA= BeautifulSoup(page_responseAOA.content, "html.parser")
page_contentQNT= BeautifulSoup(page_responseQNT.content, "html.parser")

#we use the html parser to parse the url content and store it in a variable.






"""

Elastos (ELA) bills itself as the 'first completely safe and decentralized infrastructure for the internet'. 
Its vision is to create a blockchain-powered decentralized internet that enables digital rights and secure 
transactions. Elastos uses the Internet as the base-layer infrastructure and separates network communications 
from application computing. It prohibits apps from directly accessing the network so as to prevent malicious attacks. 
Elastos is merged mined with Bitcoin to optimize energy efficiency and leverage the security of the Bitcoin network 
for Elastos applications. Sidechains are also included as an additional layer of security.


Kucoin Shares (KCS) is an exchange based token and native currency of the 
Kucoin crypto exchange. Holders of the token are able to reap the rewards 
from the success of the exchange as 50% of its overall trading fee revenue is shared with 
holders through the tokens. Rewards, received in the form of dividends, are proportionate 
to the amount of Kucoin Shares one holds.

Wanchain (WAN) aims to build a 'super financial market' by connecting distinct digital assets. 
Its key features are cross-chain interoperability, privacy, and smart contract functionality. 
Wanchain connects and facilitates the transfer of value between different blockchains in a 
distributed fashion. Public or private blockchains can integrate with Wanchain to establish connections 
between different ledgers and perform inter-ledger asset transfers. The Wanchain ledger supports not only 
smart contracts, but also token exchange privacy protection. Use cases of the Wanchain include asset transfers, 
loan origination, and credit payments. Wanchain is part of the Enterprise Ethereum Alliance (EEA) and Blockchain 
Interoperability Alliance (BIA). The latter comprises ICON, Aion, and Wanchain and has the shared goal of promoting 
interconnectivity between isolated blockchain networks.


"""
# Out:
# "\n\nElastos (ELA) bills itself as the 'first completely safe and decentralized infrastructure for the internet'. \nIts vision is to create a blockchain-powered decentralized internet that enables digital rights and secure \ntransactions. Elastos uses the Internet as the base-layer infrastructure and separates network communications \nfrom application computing. It prohibits apps from directly accessing the network so as to prevent malicious attacks. \nElastos is merged mined with Bitcoin to optimize energy efficiency and leverage the security of the Bitcoin network \nfor Elastos applications. Sidechains are also included as an additional layer of security.\n\n\nKucoin Shares (KCS) is an exchange based token and native currency of the \nKucoin crypto exchange. Holders of the token are able to reap the rewards \nfrom the success of the exchange as 50% of its overall trading fee revenue is shared with \nholders through the tokens. Rewards, received in the form of dividends, are proport
# ...

# %%
VETcontent = page_contentVET.findAll('tr')
TUSDcontent = page_contentTUSD.findAll('tr')
XVGcontent = page_contentXVG.findAll('tr')
AEcontent = page_contentAE.findAll('tr')
STRATcontent = page_contentSTRAT.findAll('tr')
LRCcontent = page_contentLRC.findAll('tr')
AOAcontent = page_contentAOA.findAll('tr')
QNTcontent = page_contentQNT.findAll('tr')

# %%
listofhistoricaldataVET= []
for point in range(len(VETcontent)):
    listofhistoricaldataVET.append(VETcontent[point].text)

listofhistoricaldataTUSD= []
for point in range(len(TUSDcontent)):
    listofhistoricaldataTUSD.append(TUSDcontent[point].text)

listofhistoricaldataXVG= []
for point in range(len(XVGcontent)):
    listofhistoricaldataXVG.append(XVGcontent[point].text)

listofhistoricaldataAE= []
for point in range(len(AEcontent)):
    listofhistoricaldataAE.append(AEcontent[point].text)


listofhistoricaldataSTRAT= []
for point in range(len(STRATcontent)):
    listofhistoricaldataSTRAT.append(STRATcontent[point].text)
    
    
listofhistoricaldataLRC= []
for point in range(len(LRCcontent)):
    listofhistoricaldataLRC.append(LRCcontent[point].text)

listofhistoricaldataAOA= []
for point in range(len(AOAcontent)):
    listofhistoricaldataAOA.append(AOAcontent[point].text)

listofhistoricaldataQNT= []
for point in range(len(QNTcontent)):
    listofhistoricaldataQNT.append(QNTcontent[point].text)
    
# listofhistoricaldataELA= []
# for point in range(len(ELAcontent)):
#     listofhistoricaldataELA.append(ELAcontent[point].text)
    
# listofhistoricaldataKCS= []
# for point in range(len(KCScontent)):
#     listofhistoricaldataKCS.append(KCScontent[point].text)
    
# listofhistoricaldataWAN= []
# for point in range(len(WANcontent)):
#     listofhistoricaldataWAN.append(WANcontent[point].text)

# %%
listofhistoricaldataVET
# Out:
# ['\nDate\nOpen*\nHigh\nLow\nClose**\nVolume\nMarket Cap\n',
#  '\nFeb 13, 2019\n0.003937\n0.003976\n0.003859\n0.003876\n3,182,996\n214,919,064\n',
#  '\nFeb 12, 2019\n0.003921\n0.003950\n0.003843\n0.003924\n3,227,572\n217,588,784\n',
#  '\nFeb 11, 2019\n0.004048\n0.004048\n0.003908\n0.003909\n3,260,261\n216,769,109\n',
#  '\nFeb 10, 2019\n0.004022\n0.004131\n0.003939\n0.004044\n5,229,670\n224,236,626\n',
#  '\nFeb 09, 2019\n0.003982\n0.004019\n0.003900\n0.004006\n3,591,370\n222,158,015\n',
#  '\nFeb 08, 2019\n0.003693\n0.004055\n0.003656\n0.003966\n5,403,796\n219,930,760\n',
#  '\nFeb 07, 2019\n0.003640\n0.003762\n0.003626\n0.003694\n3,386,472\n204,868,148\n',
#  '\nFeb 06, 2019\n0.003774\n0.003784\n0.003620\n0.003637\n4,506,774\n201,682,749\n',
#  '\nFeb 05, 2019\n0.003820\n0.003852\n0.003757\n0.003786\n4,009,846\n209,969,687\n',
#  '\nFeb 04, 2019\n0.003865\n0.003876\n0.003786\n0.003827\n3,435,089\n212,240,113\n',
# ...

# %%
newsymbols= ['VET', 'TUSD', 'XVG', 'AE', 'AOA', 'QNT', 'STRAT', "LRC"]

# %%
dataLRC= []
for a in listofhistoricaldataLRC:
    dataLRC.append(a.split('\n'))

dataSTRAT= []
for a in listofhistoricaldataSTRAT:
    dataSTRAT.append(a.split('\n'))
    
dataQNT= []
for a in listofhistoricaldataQNT:
    dataQNT.append(a.split('\n'))

dataQNT= []
for a in listofhistoricaldataQNT:
    dataQNT.append(a.split('\n'))

dataAOA= []
for a in listofhistoricaldataAOA:
    dataAOA.append(a.split('\n'))

dataAE= []
for a in listofhistoricaldataAE:
    dataAE.append(a.split('\n'))

dataXVG= []
for a in listofhistoricaldataXVG:
    dataXVG.append(a.split('\n'))

dataTUSD= []
for a in listofhistoricaldataTUSD:
    dataTUSD.append(a.split('\n'))

dataVET= []
for a in listofhistoricaldataVET:
    dataVET.append(a.split('\n'))

# dataELA= []
# for a in listofhistoricaldataELA:
#     dataELA.append(a.split('\n'))

# dataKCS= []
# for a in listofhistoricaldataKCS:
#     dataKCS.append(a.split('\n'))
    
# dataWAN= []
# for a in listofhistoricaldataWAN:
#     dataWAN.append(a.split('\n'))

# %%
newsymbols
# Out:
# ['VET', 'TUSD', 'XVG', 'AE', 'AOA', 'QNT', 'STRAT', 'LRC']

# %%
import pandas as pd

PandadataframeVET= pd.DataFrame(dataVET) 
PandadataframeTUSD= pd.DataFrame(dataTUSD) 
PandadataframeXVG= pd.DataFrame(dataXVG) 
PandadataframeAE= pd.DataFrame(dataAE) 
PandadataframeAOA= pd.DataFrame(dataAOA) 
PandadataframeQNT= pd.DataFrame(dataQNT) 
PandadataframeSTRAT= pd.DataFrame(dataSTRAT) 
PandadataframeLRC= pd.DataFrame(dataLRC)


# PandadataframeELA= pd.DataFrame(dataELA) 
# PandadataframeKCS= pd.DataFrame(dataKCS)
# PandadataframeWAN= pd.DataFrame(dataWAN)

# %%
newsymbols
# Out:
# ['VET', 'TUSD', 'XVG', 'AE', 'AOA', 'QNT', 'STRAT', 'LRC']

# %%
PandadataframeLRC
# Out:
#     0             1                         2         3         4   \
# 0               Date                     Open*      High       Low
# 1       Feb 13, 2019                  0.053778  0.054505  0.053050
# 2       Feb 12, 2019                  0.053781  0.054004  0.053102
# 3       Feb 11, 2019                  0.055186  0.055490  0.053467
# 4       Feb 10, 2019                  0.054593  0.055479  0.052695
# 5       Feb 09, 2019                  0.055369  0.055817  0.053497
# 6       Feb 08, 2019                  0.051758  0.056250  0.051421
# 7       Feb 07, 2019                  0.051393  0.053210  0.051219
# 8       Feb 06, 2019                  0.053982  0.054017  0.050852
# 9       Feb 05, 2019                  0.054999  0.055202  0.053696
# 10      Feb 04, 2019                  0.056346  0.056429  0.054930
# 11      Feb 03, 2019                  0.056893  0.058822  0.056048
# 12      Feb 02, 2019                  0.057263  0.058469  0.055220
# ...

# %%
#drops the end/blank data points at the end of the dataframe
dfVETformatted = PandadataframeVET.drop([x for x in range(196,206)])
dfTUSDformatted = PandadataframeTUSD.drop([x for x in range(328,357)])
dfXVGformatted = PandadataframeXVG.drop([x for x in range(328,1585)])
dfAEformatted = PandadataframeAE.drop([x for x in range(328,635)])
dfAOAformatted = PandadataframeAOA.drop([x for x in range(234,245)])
dfQNTformatted = PandadataframeQNT.drop([x for x in range(189, len(PandadataframeQNT))])
dfSTRATformatted = PandadataframeSTRAT.drop([x for x in range(328, len(PandadataframeSTRAT))])
dfLRCformatted = PandadataframeLRC.drop([x for x in range(328, len(PandadataframeLRC))])


# dfWANformatted = PandadataframeWAN.drop([x for x in range(327,338)])
# dfKCSformatted = PandadataframeKCS.drop([x for x in range(477,488)])


#drops the last three columns with no data associated
dfVETformatted = dfVETformatted.drop(dfVETformatted.columns[[8, 9, 10]], axis=1)
dfTUSDformatted = dfTUSDformatted.drop(dfTUSDformatted.columns[[8, 9, 10]], axis=1)
dfXVGformatted = dfXVGformatted.drop(dfXVGformatted.columns[[8, 9, 10]], axis=1)
dfAOAformatted = dfAOAformatted.drop(dfAOAformatted.columns[[8, 9, 10]], axis=1)
dfAEformatted = dfAEformatted.drop(dfAEformatted.columns[[8, 9, 10]], axis=1)
dfQNTformatted = dfQNTformatted.drop(dfQNTformatted.columns[[8, 9, 10]], axis=1)
dfSTRATformatted = dfSTRATformatted.drop(dfSTRATformatted.columns[[8, 9, 10]], axis=1)
dfLRCformatted = dfLRCformatted.drop(dfLRCformatted.columns[[8, 9, 10]], axis=1)




# dfWANformatted = dfWANformatted.drop(dfWANformatted.columns[[8, 9, 10]], axis=1)
# dfKCSformatted = dfKCSformatted.drop(dfKCSformatted.columns[[8, 9, 10]], axis=1)

#renames the columns and drops the top row
dfVETformatted.rename(columns=dfVETformatted.iloc[0])#.drop(dfVETformatted.index[0])
dfTUSDformatted.rename(columns=dfTUSDformatted.iloc[0])#.drop(dfTUSDformatted.index[0])
dfXVGformatted.rename(columns=dfXVGformatted.iloc[0])#.drop(dfXVGformatted.index[0])
dfAOAformatted.rename(columns=dfAOAformatted.iloc[0])#.drop(dfAOAformatted.index[0])
dfAEformatted.rename(columns=dfAEformatted.iloc[0])#.drop(dfAEformatted.index[0])
dfQNTformatted.rename(columns=dfQNTformatted.iloc[0])#.drop(dfQNTformatted.index[0])
dfSTRATformatted.rename(columns=dfSTRATformatted.iloc[0])#.drop(dfSTRATformatted.index[0])
dfLRCformatted.rename(columns=dfLRCformatted.iloc[0])#.drop(dfLRCformatted.index[0])



# dfWANformatted.rename(columns=dfWANformatted.iloc[0]).drop(dfWANformatted.index[0])
# dfKCSformatted.rename(columns=dfKCSformatted.iloc[0]).drop(dfKCSformatted.index[0])

dfVEThistorical = dfVETformatted.rename(columns=dfVETformatted.iloc[0])#.drop(([x for x in range(0,3)]))
dfTUSDhistorical = dfTUSDformatted.rename(columns=dfTUSDformatted.iloc[0])#.drop(([x for x in range(0,3)]))
dfXVGhistorical = dfXVGformatted.rename(columns=dfXVGformatted.iloc[0])#.drop(([x for x in range(0,3)]))
dfAOAhistorical = dfAOAformatted.rename(columns=dfAOAformatted.iloc[0])#.drop(([x for x in range(0,3)]))
dfAEhistorical = dfAEformatted.rename(columns=dfAEformatted.iloc[0])#.drop(([x for x in range(0,3)]))
dfQNThistorical = dfQNTformatted.rename(columns=dfQNTformatted.iloc[0])#.drop(([x for x in range(0,3)]))
dfSTRAThistorical = dfSTRATformatted.rename(columns=dfSTRATformatted.iloc[0])#.drop(([x for x in range(0,3)]))
dfLRChistorical = dfLRCformatted.rename(columns=dfLRCformatted.iloc[0])#.drop(([x for x in range(0,3)]))



# dfWANhistorical = dfWANformatted.rename(columns=dfWANformatted.iloc[0]).drop(dfWANformatted.index[0])
# dfKCShistorical = dfKCSformatted.rename(columns=dfKCSformatted.iloc[0]).drop(dfKCSformatted.index[0])

# %%
dfLRChistorical.head()
# Out:
#              Date     Open*      High       Low   Close**     Volume  \
# 0            Date     Open*      High       Low   Close**     Volume
# 1    Feb 13, 2019  0.053778  0.054505  0.053050  0.053468    906,239
# 2    Feb 12, 2019  0.053781  0.054004  0.053102  0.053773    764,100
# 3    Feb 11, 2019  0.055186  0.055490  0.053467  0.053827    990,393
# 4    Feb 10, 2019  0.054593  0.055479  0.052695  0.055287  1,016,308
#
#    Market Cap
# 0  Market Cap
# 1  42,185,329
# 2  42,425,924
# 3  42,468,467
# 4  43,620,761

# %%
dfLRChistorical.to_csv("LRC.csv")

# %%
dfQNThistorical.to_csv("QNT.csv")

# %%
dfSTRAThistorical.to_csv("STRAT.csv")

# %%
dfAOAhistorical.to_csv("AOA.csv")

# %%
dfAEhistorical.to_csv("AE.csv")

# %%
dfXVGhistorical.to_csv("XVG.csv")

# %%
dfVEThistorical.to_csv("VET.csv")

# %%
dfTUSDhistorical.to_csv("TUSD.csv")

# %%
dfTUSDhistorical
# Out:
#                 Date     Open*  High       Low   Close**      Volume  \
# 0               Date     Open*  High       Low   Close**      Volume
# 1       Feb 13, 2019      1.02  1.02      1.01      1.01  47,129,353
# 2       Feb 12, 2019      1.01  1.02      1.01      1.02  60,256,778
# 3       Feb 11, 2019      1.02  1.02      1.01      1.01  38,129,351
# 4       Feb 10, 2019      1.01  1.02      1.01      1.02  45,775,593
# 5       Feb 09, 2019      1.01  1.02      1.01      1.01  48,370,217
# 6       Feb 08, 2019      1.01  1.02      1.00      1.01  89,362,717
# 7       Feb 07, 2019      1.01  1.01      1.01      1.01  30,327,998
# 8       Feb 06, 2019      1.01  1.02      1.01      1.01  56,699,075
# 9       Feb 05, 2019      1.01  1.02      1.01      1.01  36,259,478
# 10      Feb 04, 2019      1.01  1.02      1.01      1.01  34,509,169
# 11      Feb 03, 2019      1.01  1.02      1.01      1.01  34,914,547
# 12      Feb 02, 2019      1.02  1.02      1.01      1.01  35,543,272
# ...

# %%
# !pip install nbmerge
# !pip install nbmerge

nbmerge BottomthreeCryptos.ipynb Crypto.ipynb > merged.ipynb
# Out:
#   File "<ipython-input-6-944b607d4367>", line 4
#     nbmerge BottomthreeCryptos.ipynb Crypto.ipynb > merged.ipynb
#                              ^
# SyntaxError: invalid syntax

# %%
# !pip install alpha_vantage

# %%
import alpha_vantage
# %matplotlib inline
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib
import matplotlib.pyplot as plt
#importing the required tools for alpha advantage api

apikey = 'JJXIFEPV0N66DTON'
#apikey obtained through alpha vantage website

# %%
#alpha vantage api syntax, requiring a function, symbol and market
#using the api key to access api, resulted in output being a pandas dataframe
cc = CryptoCurrencies(key=apikey, output_format='pandas')
data, meta_data = cc.get_digital_currency_daily(symbol='XRP', market='USD')

# %%
bitcoin_meta
# Out:
# {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#  '2. Digital Currency Code': 'BTC',
#  '3. Digital Currency Name': 'Bitcoin',
#  '4. Market Code': 'USD',
#  '5. Market Name': 'United States Dollar',
#  '6. Last Refreshed': '2019-02-11 (end of day)',
#  '7. Time Zone': 'UTC'}

# %%
bitcoin_data.head()
# Out:
#             1a. open (USD)  1b. open (USD)  2a. high (USD)  2b. high (USD)  \
# date
# 2014-04-01      468.480106      468.480106      491.267273      491.267273
# 2014-04-02      479.679615      479.679615      494.111337      494.111337
# 2014-04-03      437.322089      437.322089      452.441405      452.441405
# 2014-04-04      448.597144      448.597144      457.327172      457.327172
# 2014-04-05      450.027798      450.027798      466.385470      466.385470
#
#             3a. low (USD)  3b. low (USD)  4a. close (USD)  4b. close (USD)  \
# date
# 2014-04-01     468.480106     468.480106       479.023434       479.023434
# 2014-04-02     430.725909     430.725909       438.377824       438.377824
# 2014-04-03     414.811104     414.811104       446.819755       446.819755
# 2014-04-04     429.184117     429.184117       451.645992       451.645992
# 2014-04-05     445.107783     445.107783       464.379322       464.379322
#
#                5. volume  6. market cap (USD)
# ...

# %%
ethereum_meta
# Out:
# {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#  '2. Digital Currency Code': 'ETH',
#  '3. Digital Currency Name': 'Ethereum',
#  '4. Market Code': 'USD',
#  '5. Market Name': 'United States Dollar',
#  '6. Last Refreshed': '2019-02-11 (end of day)',
#  '7. Time Zone': 'UTC'}

# %%
ethereum_data.head()
# Out:
#             1a. open (USD)  1b. open (USD)  2a. high (USD)  2b. high (USD)  \
# date
# 2015-08-08         3.00000         3.00000         3.00000         3.00000
# 2015-08-09         1.19999         1.19999         1.19999         1.19999
# 2015-08-10         1.19999         1.19999         1.19999         1.19999
# 2015-08-11         1.19999         1.19999         1.19999         1.19999
# 2015-08-12         0.99000         0.99000         1.28800         1.28800
#
#             3a. low (USD)  3b. low (USD)  4a. close (USD)  4b. close (USD)  \
# date
# 2015-08-08        0.15000        0.15000          1.19999          1.19999
# 2015-08-09        1.19999        1.19999          1.19999          1.19999
# 2015-08-10        1.19999        1.19999          1.19999          1.19999
# 2015-08-11        0.65038        0.65038          0.99000          0.99000
# 2015-08-12        0.90500        0.90500          1.28800          1.28800
#
#               5. volume  6. market cap (USD)
# ...

# %%
xrp_meta
# Out:
# {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#  '2. Digital Currency Code': 'XRP',
#  '3. Digital Currency Name': 'Ripple',
#  '4. Market Code': 'USD',
#  '5. Market Name': 'United States Dollar',
#  '6. Last Refreshed': '2019-02-11 (end of day)',
#  '7. Time Zone': 'UTC'}

# %%
xrp_data.head()
# Out:
#             1a. open (USD)  1b. open (USD)  2a. high (USD)  2b. high (USD)  \
# date
# 2014-04-09        0.009407        0.009407        0.009407        0.009407
# 2014-04-10        0.008333        0.008333        0.008333        0.008333
# 2014-04-11        0.006796        0.006796        0.006983        0.006983
# 2014-04-12        0.006727        0.006727        0.006893        0.006893
# 2014-04-13        0.006880        0.006880        0.006880        0.006880
#
#             3a. low (USD)  3b. low (USD)  4a. close (USD)  4b. close (USD)  \
# date
# 2014-04-09       0.008333       0.008333         0.008333         0.008333
# 2014-04-10       0.006796       0.006796         0.006796         0.006796
# 2014-04-11       0.006727       0.006727         0.006727         0.006727
# 2014-04-12       0.006727       0.006727         0.006880         0.006880
# 2014-04-13       0.006515       0.006515         0.006515         0.006515
#
#                5. volume  6. market cap (USD)
# ...
