# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
BTC = pd.read_csv('BTC_reshaped.csv').drop(['Unnamed: 0'], axis=1)
ETH = pd.read_csv('ETH_reshaped.csv').drop(['Unnamed: 0'], axis=1)
XRP = pd.read_csv('XRP_reshaped.csv').drop(['Unnamed: 0'], axis=1)
DOGE = pd.read_csv('DOGE.csv').drop(['Unnamed: 0'], axis=1)
VET = pd.read_csv('VET.csv').drop(['Unnamed: 0'], axis=1)
TUSD = pd.read_csv('TUSD.csv').drop(['Unnamed: 0'], axis=1)
XVG = pd.read_csv('XVG.csv').drop(['Unnamed: 0'], axis=1)
AE = pd.read_csv('AE.csv').drop(['Unnamed: 0'], axis=1)
STRAT = pd.read_csv('STRAT.csv').drop(['Unnamed: 0'], axis=1)
LRC = pd.read_csv('LRC.csv').drop(['Unnamed: 0'], axis=1)
AOA = pd.read_csv('AOA.csv').drop(['Unnamed: 0'], axis=1)
QNT = pd.read_csv('QNT.csv').drop(['Unnamed: 0'], axis=1)
WAN = pd.read_csv('WAN_reshaped.csv').drop(['Unnamed: 0'], axis=1).drop(['Unnamed: 0.1'], axis=1)
ELA = pd.read_csv('ELA_reshaped.csv').drop(['Unnamed: 0'], axis=1).drop(['Unnamed: 0.1'], axis=1)
KCS = pd.read_csv('KCS_reshaped.csv').drop(['Unnamed: 0'], axis=1).drop(['Unnamed: 0.1'], axis=1)

# %%
BTC.columns
# Out:
# Index(['Date', 'Open(USD)', 'High(USD)', 'Low(USD)', 'Close(USD)', 'Volume',
#        'Market Cap(USD)', 'Close Percent Change'],
#       dtype='object')

# %%
VET.columns
# Out:
# Index(['Date', 'Open*', 'High', 'Low', 'Close**', 'Volume', 'Market Cap',
#        'Close Percent Change'],
#       dtype='object')

# %%
VET.drop([193])
# Out:
#              Date     Open*      High       Low   Close**      Volume  \
# 0    Feb 11, 2019  0.004048  0.004048  0.003908  0.003909   3,260,261
# 1    Feb 10, 2019  0.004022  0.004131  0.003939  0.004044   5,229,670
# 2    Feb 09, 2019  0.003982  0.004019  0.003900  0.004006   3,591,370
# 3    Feb 08, 2019  0.003693  0.004055  0.003656  0.003966   5,403,796
# 4    Feb 07, 2019  0.003640  0.003762  0.003626  0.003694   3,386,472
# 5    Feb 06, 2019  0.003774  0.003784  0.003620  0.003637   4,506,774
# 6    Feb 05, 2019  0.003820  0.003852  0.003757  0.003786   4,009,846
# 7    Feb 04, 2019  0.003865  0.003876  0.003786  0.003827   3,435,089
# 8    Feb 03, 2019  0.003937  0.003949  0.003830  0.003864   2,778,666
# 9    Feb 02, 2019  0.003917  0.003952  0.003866  0.003952   2,829,236
# 10   Feb 01, 2019  0.003910  0.003957  0.003817  0.003928   3,570,933
# 11   Jan 31, 2019  0.004024  0.004069  0.003823  0.003909   6,030,416
# 184    509,765,986              0.012335
# 185    540,526,727              0.060379
# 186    647,872,121              0.198625
# 187    597,558,040             -0.077634
# 188    715,321,715              0.197012
# 189    744,440,996              0.040701
# 190    780,858,121              0.048942
# 191    739,350,252             -0.053121
# 192    848,840,080              0.148054
#
# [193 rows x 8 columns]

# %%
BTC = BTC.rename(columns={'Close(USD)': "C1"})
ETH = ETH.rename(columns={'Close(USD)': "C2"})
XRP = XRP.rename(columns={'Close(USD)': "C3"})
DOGE = DOGE.rename(columns={'Close(USD)': "C4"})
VET = VET.rename(columns={'Close**': "C5"}).drop([193])
TUSD = TUSD.rename(columns={'Close**': "C6"})
XVG = XVG.rename(columns={'Close**': "C7"})
AE = AE.rename(columns={'Close**': "C8"})
STRAT = STRAT.rename(columns={'Close**': "C9"})
LRC = LRC.rename(columns={'Close**': "C10"})
AOA = AOA.rename(columns={'Close**': "C11"})
QNT = QNT.rename(columns={'Close**': "C12"})
WAN = WAN.rename(columns={'Close**': "C13"})
ELA = ELA.rename(columns={'Close**': "C14"})
KCS = KCS.rename(columns={'Close**': "C15"})

# %%
VET.tail()
# Out:
#              Date     Open*      High       Low        C5      Volume  \
# 188  Aug 07, 2018  0.013315  0.014457  0.012163  0.012899  21,022,400
# 189  Aug 06, 2018  0.013963  0.014308  0.012930  0.013424  18,774,100
# 190  Aug 05, 2018  0.013428  0.014295  0.012696  0.014081  19,746,000
# 191  Aug 04, 2018  0.015218  0.015944  0.012377  0.013333  27,059,500
# 192  Aug 03, 2018  0.015041  0.015730  0.014938  0.015307  46,250,600
#
#       Market Cap  Close Percent Change
# 188  715,321,715              0.197012
# 189  744,440,996              0.040701
# 190  780,858,121              0.048942
# 191  739,350,252             -0.053121
# 192  848,840,080              0.148054

# %%
closing_price = pd.concat([BTC.loc[:, ['Date']], BTC.loc[:, ['C1']],
                        ETH.loc[:, ['C2']], XRP.loc[:, ['C3']],
                        DOGE.loc[:, ['C4']], VET.loc[:, ['C5']],
                        TUSD.loc[:, ['C6']], XVG.loc[:, ['C7']],
                        AE.loc[:, ['C8']], STRAT.loc[:, ['C9']],
                        LRC.loc[:, ['C10']], AOA.loc[:, ['C11']],
                        QNT.loc[:, ['C12']], WAN.loc[:, ['C13']],
                        ELA.loc[:, ['C14']], KCS.loc[:, ['C15']]], axis=1, join_axes=[BTC.index])

# %%
closing_price.tail()
# Out:
#            Date           C1          C2        C3        C4   C5        C6  \
# 320  2018-03-28  7951.857952  445.567479  0.574627  0.003346  NaN  1.000000
# 321  2018-03-27  7822.070474  449.416666  0.572638  0.003253  NaN  0.999424
# 322  2018-03-26  8174.560383  487.701665  0.590579  0.003353  NaN  1.000000
# 323  2018-03-25  8481.612131  522.843919  0.633955  0.003593  NaN  0.995833
# 324  2018-03-24  8602.510596  524.791927  0.630651  0.003689  NaN  0.998900
#
#            C7    C8    C9       C10  C11  C12   C13    C14   C15
# 320  0.041806  1.64  4.58  0.433242  NaN  NaN  3.42  33.12  2.62
# 321  0.039978  1.58  4.40  0.405681  NaN  NaN  3.35  30.47  2.54
# 322  0.044531  1.61  4.91  0.423541  NaN  NaN  3.80  33.29  2.71
# 323  0.040702  1.64  5.43  0.470227  NaN  NaN  4.15  35.61  3.03
# 324  0.044792  1.67  5.21  0.503488  NaN  NaN  4.19  37.10  2.91

# %%
closing_price = closing_price.rename(columns={ closing_price.columns[1]: "BTC Closing Price", 
                                        closing_price.columns[2]: "ETH Closing Price",
                                       closing_price.columns[3]: "XRP Closing Price",
                                        closing_price.columns[4]: "DOGE Closing Price",
                                        closing_price.columns[5]: "VET Closing Price",
                                        closing_price.columns[6]: "TUSD Closing Price",
                                        closing_price.columns[7]: "XVG Closing Price",
                                        closing_price.columns[8]: "AE Closing Price",
                                        closing_price.columns[9]: "STRAT Closing Price",
                                        closing_price.columns[10]: "LRC Closing Price",
                                        closing_price.columns[11]: "AOA Closing Price",
                                        closing_price.columns[12]: "QNT Closing Price",
                                        closing_price.columns[13]: "WAN Closing Price",
                                       closing_price.columns[14]: "ELA Closing Price",
                                       closing_price.columns[15]: "KCS Closing Price"})

# %%
closing_price.head()
# Out:
#          Date  BTC Closing Price  ETH Closing Price  XRP Closing Price  \
# 0  2019-02-11        3643.486916         121.159210           0.304300
# 1  2019-02-10        3686.977610         124.950229           0.308912
# 2  2019-02-09        3665.169880         119.776270           0.310646
# 3  2019-02-08        3658.389649         119.653788           0.312029
# 4  2019-02-07        3390.505404         104.173485           0.291644
#
#    DOGE Closing Price VET Closing Price  TUSD Closing Price  \
# 0            0.001972          0.003909                1.01
# 1            0.001989          0.004044                1.02
# 2            0.002009          0.004006                1.01
# 3            0.001969          0.003966                1.01
# 4            0.001931          0.003694                1.01
#
#    XVG Closing Price  AE Closing Price  STRAT Closing Price  \
# 0           0.005994          0.387543             0.820662
# 1           0.006171          0.394485             0.818007
# 2           0.006130          0.401183             0.803968
# 3           0.006052          0.392337             0.817695
# 4           0.005644          0.362809             0.751636
#
#    LRC Closing Price  AOA Closing Price  QNT Closing Price WAN Closing Price  \
# 0           0.053827           0.007514               3.99          0.293568
# 1           0.055287           0.007180               4.64          0.291913
# 2           0.054550           0.008425               4.24          0.289930
# 3           0.055106           0.008070               4.14          0.292698
# 4           0.051812           0.007548               2.95          0.272198
#
#    ELA Closing Price  KCS Closing Price
# 0               2.25           0.360186
# 1               2.36           0.370683
# 2               2.28           0.373724
# 3               2.30           0.368694
# 4               2.11           0.348911

# %%
closing_price.to_csv('Closing_price.csv')
